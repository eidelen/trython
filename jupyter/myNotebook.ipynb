# %% [markdown]
# # My first Notebook

# %%
# import some packages

from IPython.display import display
from ipywidgets import *
from PIL import Image

# %%
a, b = (2, 4)
print( a + b)
# Out:
# 6

# %% [markdown]
# Select path and load the image

# %%
img = Image.open("test.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=311x229>

# %%
fle = widgets.FileUpload(
    description= 'Title',
    accept='*.*',
    multiple=False,
)

# %%
fle
# Out:
# FileUpload(value=(), accept='*.*', description='Title')

# %%
print(fle)
print(fle.value)
print(fle.value[0]['name'])
f_name = fle.value[0]['name']
with open(f_name, 'wb') as output_file: 
    contentptr = fle.value[0]['content']   
    output_file.write(contentptr)
# Out:
# FileUpload(value=({'name': 'inf.png', 'type': 'image/png', 'size': 168310, 'content': <memory at 0x0000022D53B17E80>, 'last_modified': datetime.datetime(2023, 10, 12, 7, 8, 2, 191000, tzinfo=datetime.timezone.utc)},), accept='*.*', description='Title')
# ({'name': 'inf.png', 'type': 'image/png', 'size': 168310, 'content': <memory at 0x0000022D53B17E80>, 'last_modified': datetime.datetime(2023, 10, 12, 7, 8, 2, 191000, tzinfo=datetime.timezone.utc)},)
# inf.png

# %%
img2 = Image.open(f_name)
display(img2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2492x890>

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 32B3-9BE3
#
#  Directory of C:\Users\admin\dev\trython\jupyter
#
# 11/24/2023  03:06 PM    <DIR>          .
# 11/24/2023  03:06 PM    <DIR>          ..
# 11/24/2023  03:07 PM    <DIR>          .idea
# 11/24/2023  02:10 PM    <DIR>          .ipynb_checkpoints
# 11/24/2023  03:06 PM         5,719,752 garten-5a.png
# 11/24/2023  02:59 PM            46,120 myNotebook.ipynb
# 11/24/2023  11:40 AM               149 notes.txt
# 11/24/2023  11:33 AM            25,032 test.png
# 11/24/2023  11:16 AM    <DIR>          venv
# 11/24/2023  03:04 PM                 0 z_merged_output.txt
#                5 File(s)      5,791,053 bytes
#                5 Dir(s)  404,136,857,600 bytes free
