# %% [markdown]
# # My first Notebook

# %%
# import some packages

from IPython.display import display
from ipywidgets import *
from PIL import Image

# %%
a, b = (2, 4)
print( a + b)
# Out:
# 6

# %% [markdown]
# Select path and load the image

# %%
img = Image.open("test.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=311x229>

# %%
fle = widgets.FileUpload(
    description= 'Title',
    accept='*.*',
    multiple=False,
)

# %%
fle
# Out:
# FileUpload(value=({'name': 'garten-5a.png', 'type': 'image/png', 'size': 5719752, 'content': <memory at 0x0000…

# %%
print(fle)
# Out:
# FileUpload(value=({'name': 'garten-5a.png', 'type': 'image/png', 'size': 5719752, 'content': <memory at 0x0000022D51871000>, 'last_modified': datetime.datetime(2023, 11, 8, 12, 56, 25, 683000, tzinfo=datetime.timezone.utc)},), accept='*.*', description='Title')

# %%
img2 = Image.open("garten-5a.png")
display(img2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 img2 = Image.open("garten-5a.png")
#       2 display(img2)
#
# File ~\dev\trython\jupyter\venv\lib\site-packages\PIL\Image.py:3243, in open(fp, mode, formats)
#    3240     filename = fp
#    3242 if filename:
# -> 3243     fp = builtins.open(filename, "rb")
#    3244     exclusive_fp = True
#    3246 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'garten-5a.png'
